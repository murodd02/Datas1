# %% [markdown]
# <a href="https://colab.research.google.com/github/murodd02/Datas1/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('bcd'), index=['Olma','Anor','Uzum'])
df2 = pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abc'), index=['Olma','Anor','Qovun','Anjir'])

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1.add(df2, fill_value=0)
# Out:
#          a     b     c    d
# Anjir  9.0  10.0  11.0  NaN
# Anor   3.0   7.0   9.0  5.0
# Olma   0.0   1.0   3.0  2.0
# Qovun  6.0   7.0   8.0  NaN
# Uzum   NaN   6.0   7.0  8.0

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df1.rsub(2)
# Out:
#         b    c    d
# Olma  2.0  1.0  0.0
# Anor -1.0 -2.0 -3.0
# Uzum -4.0 -5.0 -6.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df2.rsub(2)
# Out:
#          a    b    c
# Olma   2.0  1.0  0.0
# Anor  -1.0 -2.0 -3.0
# Qovun -4.0 -5.0 -6.0
# Anjir -7.0 -8.0 -9.0

# %%
df = pd.DataFrame(np.arange(1,13.).reshape(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0   2.0    3.0    4.0
# b   5.0   6.0    7.0    8.0
# c   9.0  10.0   11.0   12.0

# %%
obj = pd.Series([1,1,2,2], index=df.columns)
obj
# Out:
# Olma     1
# Anor     1
# Qovun    2
# Anjir    2
# dtype: int64

# %%
df-obj
# Out:
#    Olma  Anor  Qovun  Anjir
# a   0.0   1.0    1.0    2.0
# b   4.0   5.0    5.0    6.0
# c   8.0   9.0    9.0   10.0

# %%
df+obj
# Out:
#    Olma  Anor  Qovun  Anjir
# a   2.0   3.0    5.0    6.0
# b   6.0   7.0    9.0   10.0
# c  10.0  11.0   13.0   14.0

# %%
obj = pd.Series([2,3,4], index=['Olma','Anjir','Uzum'])
obj
# Out:
# Olma     2
# Anjir    3
# Uzum     4
# dtype: int64

# %%
df+obj
# Out:
#    Anjir  Anor  Olma  Qovun  Uzum
# a    7.0   NaN   3.0    NaN   NaN
# b   11.0   NaN   7.0    NaN   NaN
# c   15.0   NaN  11.0    NaN   NaN

# %%
df
# Out:
#    Olma  Anor  Qovun  Anjir
# a   1.0   2.0    3.0    4.0
# b   5.0   6.0    7.0    8.0
# c   9.0  10.0   11.0   12.0

# %%
df-obj['Olma']
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -1.0   0.0    1.0    2.0
# b   3.0   4.0    5.0    6.0
# c   7.0   8.0    9.0   10.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Olma'].plot(kind='hist', bins=20, title='Olma')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Anor'].plot(kind='hist', bins=20, title='Anor')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Qovun'].plot(kind='hist', bins=20, title='Qovun')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Anjir'].plot(kind='hist', bins=20, title='Anjir')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Olma', y='Anor', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Anor', y='Qovun', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Qovun', y='Anjir', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Olma']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Olma'}, axis=1)
#               .sort_values('Olma', ascending=True))
#   xs = counted['Olma']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('Olma', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Olma')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Anor']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Anor'}, axis=1)
#               .sort_values('Anor', ascending=True))
#   xs = counted['Anor']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('Anor', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Anor')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Qovun']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Qovun'}, axis=1)
#               .sort_values('Qovun', ascending=True))
#   xs = counted['Qovun']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('Qovun', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Qovun')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Anjir']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Anjir'}, axis=1)
#               .sort_values('Anjir', ascending=True))
#   xs = counted['Anjir']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('Anjir', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Anjir')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['Olma'].plot(kind='line', figsize=(8, 4), title='Olma')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['Anor'].plot(kind='line', figsize=(8, 4), title='Anor')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Qovun'].plot(kind='line', figsize=(8, 4), title='Qovun')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Anjir'].plot(kind='line', figsize=(8, 4), title='Anjir')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df = pd.DataFrame(np.random.randn(3,4), index=list('abc'), columns=['Olma','Anor','Qovun','Anjir'])
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -0.293332  1.193496 -0.541985  0.588999
# b  2.471506  0.465826  0.082756  0.419778
# c -0.581413 -0.167492 -1.134152  0.513525

# %%
np.abs(df)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.293332  1.193496  0.541985  0.588999
# b  2.471506  0.465826  0.082756  0.419778
# c  0.581413  0.167492  1.134152  0.513525

# %%
np.round(df)
# Out:
#    Olma  Anor  Qovun  Anjir
# a  -0.0   1.0   -1.0    1.0
# b   2.0   0.0    0.0    0.0
# c  -1.0  -0.0   -1.0    1.0

# %%
df.mean()
# Out:
# Olma     0.532254
# Anor     0.497277
# Qovun   -0.531127
# Anjir    0.507434
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# a    0.236794
# b    0.859967
# c   -0.342383
# dtype: float64

# %%
f = lambda x: x.max() - x.min()

# %%
df.apply(f)
# Out:
# Olma     3.052919
# Anor     1.360987
# Qovun    1.216908
# Anjir    0.169221
# dtype: float64

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -0.293332  1.193496 -0.541985  0.588999
# b  2.471506  0.465826  0.082756  0.419778
# c -0.581413 -0.167492 -1.134152  0.513525

# %%
df.apply(np.abs)
# Out:
#        Olma      Anor     Qovun     Anjir
# a  0.293332  1.193496  0.541985  0.588999
# b  2.471506  0.465826  0.082756  0.419778
# c  0.581413  0.167492  1.134152  0.513525

# %%
df.apply(f)
# Out:
# Olma     3.052919
# Anor     1.360987
# Qovun    1.216908
# Anjir    0.169221
# dtype: float64

# %%
def foo(x):
  return pd.Series([x.min(), x.max()], index=['min','max'])

# %%
df.apply(foo)
# Out:
#          Olma      Anor     Qovun     Anjir
# min -0.581413 -0.167492 -1.134152  0.419778
# max  2.471506  1.193496  0.082756  0.588999

# %%
df
# Out:
#        Olma      Anor     Qovun     Anjir
# a -0.293332  1.193496 -0.541985  0.588999
# b  2.471506  0.465826  0.082756  0.419778
# c -0.581413 -0.167492 -1.134152  0.513525

# %%
df = pd.DataFrame(np.arange(1,13).reshape(3,4), index=list('abc'), columns=['Olma','Nok','Qovun','Anjir'])

# %%
df
# Out:
#    Olma  Nok  Qovun  Anjir
# a     1    2      3      4
# b     5    6      7      8
# c     9   10     11     12

# %%
df.applymap(lambda x: x*x)
# Out:
#    Olma  Nok  Qovun  Anjir
# a     1    4      9     16
# b    25   36     49     64
# c    81  100    121    144

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_values()
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# 0       jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1       2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2       3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3       1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4       3gcpcrec2jg473991  167763266     florida     usa  22 hours left
# ...                   ...        ...         ...     ...            ...
# 2494    3n1cn7ap9kl880319  167722715  california     usa    1 days left
# 2495    3n1cn7ap5jl884088  167762225     florida     usa  21 hours left
# 2496    3n1cn7ap9jl884191  167762226     florida     usa  21 hours left
# 2497    3n1cn7ap3jl883263  167762227     florida     usa    2 days left
# 2498    3n1cn7ap4jl884311  167762228     florida     usa  21 hours left
#
# [2499 rows x 12 columns]

# %%
df.sort_index(axis=1, inplace=True)

# %%
df.shape
# Out:
# (2499, 12)

# %%
df
# Out:
#           brand   color      condition country        lot  mileage    model  \
# 0        toyota   black   10 days left     usa  159348797   274117  cruiser
# 1          ford  silver    6 days left     usa  166951262   190552       se
# 2         dodge  silver    2 days left     usa  167655728    39590      mpv
# 3          ford    blue  22 hours left     usa  167753855    64146     door
# 4     chevrolet     red  22 hours left     usa  167763266     6654     1500
# ...         ...     ...            ...     ...        ...      ...      ...
# 2494     nissan     red    1 days left     usa  167722715    23609    versa
# 2495     nissan  silver  21 hours left     usa  167762225    34553    versa
# 2496     nissan  silver  21 hours left     usa  167762226    31594    versa
# 2497     nissan   black    2 days left     usa  167762227    32557    versa
# 2498     nissan  silver  21 hours left     usa  167762228    31371    versa
#
#       price       state   title_status                  vin  year
# 0      6300  new jersey  clean vehicle    jtezu11f88k007763  2008
# 1      2899   tennessee  clean vehicle    2fmdk3gc4bbb02217  2011
# 2      5350     georgia  clean vehicle    3c4pdcgg5jt346413  2018
# 3     25000    virginia  clean vehicle    1ftfw1et4efc23745  2014
# 4     27700     florida  clean vehicle    3gcpcrec2jg473991  2018
# ...     ...         ...            ...                  ...   ...
# 2494   7800  california  clean vehicle    3n1cn7ap9kl880319  2019
# 2495   9200     florida  clean vehicle    3n1cn7ap5jl884088  2018
# 2496   9200     florida  clean vehicle    3n1cn7ap9jl884191  2018
# 2497   9200     florida  clean vehicle    3n1cn7ap3jl883263  2018
# 2498   9200     florida  clean vehicle    3n1cn7ap4jl884311  2018
#
# [2499 rows x 12 columns]

# %%
df.sort_index(ascending=False)
# Out:
#           brand   color      condition country        lot  mileage    model  \
# 2498     nissan  silver  21 hours left     usa  167762228    31371    versa
# 2497     nissan   black    2 days left     usa  167762227    32557    versa
# 2496     nissan  silver  21 hours left     usa  167762226    31594    versa
# 2495     nissan  silver  21 hours left     usa  167762225    34553    versa
# 2494     nissan     red    1 days left     usa  167722715    23609    versa
# ...         ...     ...            ...     ...        ...      ...      ...
# 4     chevrolet     red  22 hours left     usa  167763266     6654     1500
# 3          ford    blue  22 hours left     usa  167753855    64146     door
# 2         dodge  silver    2 days left     usa  167655728    39590      mpv
# 1          ford  silver    6 days left     usa  166951262   190552       se
# 0        toyota   black   10 days left     usa  159348797   274117  cruiser
#
#       price       state   title_status                  vin  year
# 2498   9200     florida  clean vehicle    3n1cn7ap4jl884311  2018
# 2497   9200     florida  clean vehicle    3n1cn7ap3jl883263  2018
# 2496   9200     florida  clean vehicle    3n1cn7ap9jl884191  2018
# 2495   9200     florida  clean vehicle    3n1cn7ap5jl884088  2018
# 2494   7800  california  clean vehicle    3n1cn7ap9kl880319  2019
# ...     ...         ...            ...                  ...   ...
# 4     27700     florida  clean vehicle    3gcpcrec2jg473991  2018
# 3     25000    virginia  clean vehicle    1ftfw1et4efc23745  2014
# 2      5350     georgia  clean vehicle    3c4pdcgg5jt346413  2018
# 1      2899   tennessee  clean vehicle    2fmdk3gc4bbb02217  2011
# 0      6300  new jersey  clean vehicle    jtezu11f88k007763  2008
#
# [2499 rows x 12 columns]

# %%
df.sort_values(by=['year','mileage'], ascending=False)
# Out:
#           brand       color      condition country        lot  mileage  \
# 1638       ford      silver    2 days left     usa  167569992    23984
# 730   chevrolet      silver    2 days left     usa  167796080    23470
# 2336     nissan       black  14 hours left     usa  167614823    21009
# 2302     nissan      silver  21 hours left     usa  167725016    19597
# 731   chevrolet      silver   6 hours left     usa  167796081    18715
# ...         ...         ...            ...     ...        ...      ...
# 362        ford       white    2 days left     usa  167361489   206162
# 322        ford       green  19 hours left     usa  167359174        0
# 545         gmc  light blue  18 hours left     usa  167358601        0
# 405        ford       white  17 hours left     usa  167611661    41577
# 32    chevrolet         red  22 hours left     usa  167763370    46226
#
#          model  price           state       title_status                  vin  \
# 1638    fusion  20000        virginia      clean vehicle    3fa6p0cd0lr116667
# 730   traverse  30500          nevada      clean vehicle    1gnerhkw7lj115518
# 2336     rogue  19400       minnesota      clean vehicle    knmat2mvxlp505598
# 2302     rogue  21100  south carolina      clean vehicle    5n1at2mt6lc714032
# 731     impala  25000          nevada      clean vehicle    1g1105s31lu100901
# ...        ...    ...             ...                ...                  ...
# 362     pickup     25         georgia  salvage insurance    1ftdf15y2rnb12612
# 322    chassis      0      california  salvage insurance    1fdee14n7rha47894
# 545       door      0        colorado  salvage insurance    1gkfk16k5pj701631
# 405       door     25        arkansas  salvage insurance    2ftcf15y9eca14589
# 32      camaro  29800    pennsylvania      clean vehicle        1q87t3n166389
#
#       year
# 1638  2020
# 730   2020
# 2336  2020
# 2302  2020
# 731   2020
# ...    ...
# 362   1994
# 322   1994
# 545   1993
# 405   1984
# 32    1973
#
# [2499 rows x 12 columns]

# %%
df['rating'] = df['price'].rank(method='min')

# %%
df.sort_values('price')
# Out:
#               brand     color      condition country        lot  mileage  \
# 410       chevrolet     green    2 days left     usa  167425634   274706
# 330            ford     green  19 hours left     usa  167359712   296860
# 331            ford       red  17 hours left     usa  167610991   203158
# 339            ford     black    2 days left     usa  167360232   214800
# 496            ford       red  17 hours left     usa  167357804   252588
# ...             ...       ...            ...     ...        ...      ...
# 1215           ford     black  21 hours left     usa  167718954     6500
# 277           dodge      blue  21 hours left     usa  167759490    10944
# 1336           ford  no_color    2 days left     usa  167780680     9643
# 1340           ford  no_color    2 days left     usa  167780682    10536
# 502   mercedes-benz    silver    2 days left     usa  167607883    25302
#
#            model  price           state       title_status  \
# 410         door      0         arizona  salvage insurance
# 330         door      0      california  salvage insurance
# 331         door      0        illinois  salvage insurance
# 339         door      0  south carolina  salvage insurance
# 496       pickup      0        oklahoma  salvage insurance
# ...          ...    ...             ...                ...
# 1215         srw  65500         indiana      clean vehicle
# 277   challenger  67000            ohio      clean vehicle
# 1336         drw  70000        illinois      clean vehicle
# 1340         drw  74000        illinois      clean vehicle
# 502     sl-class  84900         florida      clean vehicle
#
#                       vin  year  rating
# 410     2gcec19h8s1195266  1995     1.0
# 330     1falp62w5th144314  1996     1.0
# 331     1fmzk04136ga07119  2006     1.0
# 339     3fafp37372r151014  2002     1.0
# 496     1ftef15n0tlc14455  1996     1.0
# ...                   ...   ...     ...
# 1215    1ft7w2bt0kec44818  2019  2495.0
# 277     2c3cdzl97kh518237  2019  2496.0
# 1336    1ft8w3dt3kee48276  2019  2497.0
# 1340    1ft8w4dt6ked32656  2019  2498.0
# 502     wddjk7ea3hf044968  2017  2499.0
#
# [2499 rows x 13 columns]
