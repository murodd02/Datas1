# %% [markdown]
# <a href="https://colab.research.google.com/github/murodd02/Datas1/blob/main/pandas%20arifmetik%20amallar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1], index=['a', 'c', 'e', 'f', 'g'])

# %%
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1+s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape(3,3), columns=list('bcd'), index=['Olma','Anor','Uzum'])
df2 = pd.DataFrame(np.arange(12.).reshape(4,3), columns=list('abc'), index=['Olma','Anor','Qovun','Anjir'])

# %%
df1
# Out:
#         b    c    d
# Olma  0.0  1.0  2.0
# Anor  3.0  4.0  5.0
# Uzum  6.0  7.0  8.0

# %%
df2
# Out:
#          a     b     c
# Olma   0.0   1.0   2.0
# Anor   3.0   4.0   5.0
# Qovun  6.0   7.0   8.0
# Anjir  9.0  10.0  11.0

# %%
df1+df2
# Out:
#         a    b    c   d
# Anjir NaN  NaN  NaN NaN
# Anor  NaN  7.0  9.0 NaN
# Olma  NaN  1.0  3.0 NaN
# Qovun NaN  NaN  NaN NaN
# Uzum  NaN  NaN  NaN NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#          a     b     c    d
# Anjir  9.0  10.0  11.0  NaN
# Anor   3.0   7.0   9.0  5.0
# Olma   0.0   1.0   3.0  2.0
# Qovun  6.0   7.0   8.0  NaN
# Uzum   NaN   6.0   7.0  8.0
